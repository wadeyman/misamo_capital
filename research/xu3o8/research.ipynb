# %% [markdown]
# # Research Order
# 1. Understand market structure
#            ↓
# 2. Find free data sources
#            ↓
# 3. Build clean time series
#            ↓
# 4. Study price dynamics
#            ↓
# 5. Study fundamentals
#            ↓
# 6. Build fair-value model
#            ↓
# 7. Test whether fair value predicts future returns
#            ↓
# 8. THEN build trading strategy

# %% [markdown]
# ### Introductory Findings from WNA(World Nuclear Association)
# #### Demand
# About 440 reactors with combined capacity of about 390 GWe require some 80,000 tonnes of uranium oxide concentrate containing about 67,500 tonnes of uranium (tU) from mines (or the equivalent from stockpiles or secondary sources) each year.
#
# Capacity is growing slowly, and at the same time the reactors are being
# - run more productively,
# - with higher capacity factors,
# - and reactor power levels.
# Meanwhile factors increasing fuel demand are offset by rising trend for increased efficiencies.
#
# Over last 20 years from 1970 there was a 25% reduction in uranium demand per kWh output in Europe due to such improvements, still ongoing.
#
# ``
# Each GWe of increased new capacity will require about 150 tU/yr of extra mine production routinely, and about 300-450 tU for the first fuel load.
# ``
#
# Fuel burn-up is measured in units such as MW days per tonne U (MWd/tU).

# %% [markdown]
# ### Next Steps
# ```text
#                 URANIUM RESEARCH
#                        │
#        ┌───────────────┼────────────────┐
#        ▼               ▼                ▼
#   PRICE FORMATION   FUNDAMENTALS     TRADABLE MARKET
#        │               │                │
#    What is U3O8?   Supply/demand     CME UX/ xU3O8
#    How priced?     inventories        liquidity
#    Spot vs LT      reactors          futures curve
#        │               │                │
#        └───────────────┼────────────────┘
#                        ▼
#                   FAIR VALUE
#                        │
#                        ▼
#                EXPECTED RETURNS
#                        │
#                        ▼
#                   STRATEGY
#
# ```

# %% [markdown]
# ## xU₃O₈ Research — Starting Framework
#
# ## Objective
#
# > **Understand the uranium price-generating process → estimate fair value → determine whether market prices contain predictable mispricing → only then build a trading strategy.**
#
# ---
#
# ## 1. Price Formation — How is U₃O₈ priced?
#
# ### Key Questions
# - What exactly is the U₃O₈ spot / benchmark price?
# - How is it formed if uranium does not have a deep continuous spot market?
# - How do spot, long-term contracts and futures relate?
# - What determines the CME UX futures price?
#
# ### Data Needed
# - U₃O₈ benchmark / spot price
# - Long-term uranium price
# - CME UX futures
# - Volume / open interest
# - Contract specifications
#
# ### Goal
# > Understand the **market price mechanism**.
#
# ---
#
# ## 2. Fundamentals — What should U₃O₈ be worth?
#
# ### Key Questions
# - How much uranium do reactors require?
# - How much uranium is being mined?
# - What new supply or shortages are expected?
# - What are inventories / secondary sources?
# - How much uranium are utilities contracting?
#
# ### Data Needed
#
# ```text
# Supply
# + Demand
# + Inventory
# + Contracting
# + Future reactor capacity
#
# ---
# ```
# ## 3. Tradable Market — Can I actually trade the mispricing?
#
# ### Key Questions
# What instrument am I actually trading?
# How liquid is it?
# What does the futures curve look like?
# What is spot–futures basis?
# What trading frequency is realistic?
# How quickly does new information enter the price?

# %% [markdown]
# ## Data Sources
# TradingView Watchlist:
# - UX1! (CME Futures),
# - SRUUF (Sprott Physical Uranium Trust)
# - CCJ (Cameco) to track real-time price discovery and market sentiment.
#
# - Trading Economics
# tracks global macro data and provides a clean, interactive historical chart of the uranium spot price (based on COMEX settlements) that goes back over 25 years.

# %%
import numpy as np
import pandas as pd
